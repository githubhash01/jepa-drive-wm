# %% [markdown]
# # Simple Experiment to Evalaute Masked Prediction

# %% [markdown]
# ### Loading the VJEPA Encoder and Predictor

# %%
from data.kitti import KITTISequence
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from data.kitti import KITTISequence
#
# ModuleNotFoundError: No module named 'data'

# %%
# visualise some kitti 

sequence0 = KITTISequence(sequence_id=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # visualise some kitti
#       2
# ----> 3 sequence0 = KITTISequence(sequence_id=0)
#
# NameError: name 'KITTISequence' is not defined
